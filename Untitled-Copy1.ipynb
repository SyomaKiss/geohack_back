# %%
import flask
from flask import jsonify
import geopandas as gpd
import geojsonio
from shapely.geometry import Point, Polygon
import json
from pprint import pprint
from matplotlib import pyplot as plt
import matplotlib as mpl
import numpy as np
# %matplotlib inline

# %%
# mpl.rc('image', cmap='gray')
mpl.rc('figure', figsize = (15,15))

# %%
def read_poly(df, idx=2049):
    row = df[df.ORIG_FID == idx]
    poly = row.geometry
    return json.loads(poly.to_json())

# %%
def check(poly):
    x,y = poly.exterior.xy
    x,y = np.array(x), np.array(y)
    return np.all((x>55.3) & (57.2>x)) & np.all((y>56.7) & (57.7>y))

path = 'data/perm_AOI/perm_AOI.shp'
df_all = gpd.read_file(path)
df_all = df_all[df_all.geometry.apply(check)]
df_all = df_all.reset_index()

path = 'data/changes/changes.shp'
df_target = gpd.read_file(path)
df_target = df_target[df_target.geometry.apply(lambda x: isinstance(x, Polygon))]
df_target = df_target.reset_index()

# %%
def sample(df, idxs = [1,2,3,4,5,6,7,8]):
    ret = []
    for idx in idxs:
        tmp = df[df.ORIG_FID == idx]
        area = tmp.Shape_Area.values.sum()
        length = tmp.Shape_Leng.values.sum()
        ret.append({
                    'id': idx,
                   'area': area,
                   'length': length,
                    'map_fields': read_poly(df, idx),
                   'map_ground_truth': read_poly(df, idx),
                    'status': 'ok' if idx==1 else 'danger',
        
                   })
    return {'data': ret}

# %%
df_target.to_file('tmp.geojson')

# %%
df_all.geometry.apply(lambda x: [i for i in range(len(df_target)) if x != df_target.geometry[i] and x.intersects(df_target.geometry[i])])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-97a697b6bcbb> in <module>
# ----> 1 df_all.geometry.apply(lambda x: [i for i in range(len(df_target)) if x != df_target.geometry[i] and x.intersects(df_target.geometry[i])])
#
# ~/anaconda3/envs/geohack/lib/python3.7/site-packages/geopandas/geoseries.py in apply(self, func, args, **kwargs)
#     317     @inherit_doc(pd.Series)
#     318     def apply(self, func, args=(), **kwargs):
# --> 319         result = super().apply(func, args=args, **kwargs)
#     320         if isinstance(result, GeoSeries):
#     321             if self.crs is not None:
#
# ~/anaconda3/envs/geohack/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# ...

# %%
df_all['intersected'] = df_all.geometry.apply(lambda x: [])

# %%
df_target.to_file('XY4326/tmp_target')

# %%
tmp = df_all[df_all.intersected.apply(lambda x: len(x)>0)].copy()

# %%
tmp['intersected'] = tmp.intersected.apply(lambda x: str(x))
tmp
# Out:
#       index  Id  ORIG_FID    Shape_Leng    Shape_Area  \
# 40     1153   0       455  2.247479e+03  7.939757e+04
# 49     1165   0       460  2.759744e+04  2.245003e+06
# 57     1205   0       471  2.996381e+04  3.881749e+06
# 61     1210   0       473  3.054573e+03  9.642434e+04
# 67     1231   0       486  1.870872e+03  4.011511e+04
# ...     ...  ..       ...           ...           ...
# 3651   8716   0      1414  5.465831e+06  9.115757e+08
# 3654   8719   0      1414  5.465831e+06  9.115757e+08
# 3674   8739   0      1414  5.465831e+06  9.115757e+08
# 3678   8743   0      1414  5.465831e+06  9.115757e+08
# 3680   8745   0      1414  5.465831e+06  9.115757e+08
#
#                                                geometry  \
# 40    POLYGON Z ((55.38278 56.75256 0.00000, 55.3836...
# 49    POLYGON Z ((55.47779 56.75493 0.00000, 55.4780...
# 57    POLYGON Z ((55.48147 56.76768 0.00000, 55.4818...
# 61    POLYGON Z ((55.52504 56.76604 0.00000, 55.5228...
# ...

# %%
tmp = tmp.reset_index()

# %%
tmp.to_file('XY4326/tmp')

# %%
new_target = gpd.read_file('XY4326/tmp_target/tmp_target.shp')

new_target

# %%
def get_near(df, idx=[1,3,4,5]):
    row = df.loc[idx]
    poly = row.geometry
    return json.loads(poly.to_json())

get_near(new_target, new.loc[0].inter_all)

# %%
new = gpd.read_file('XY4326/tmp2/tmp2.shp')
new['inter_all'] = new.inter_all.apply(lambda x: eval(x) if x.endswith(']') else [])

# %%
new.loc[0].inter_all
# Out:
# [0, 1]

# %%
[ 455,  460,  471,  473,  486,  487,  490,  494,  496,  499,  504, 511,  523,  528,  529,  535,  537,  538,  543,  558,  559,  560]
        564,  566,  567,  571,  573,  575,  580,  581,  582,  583,  592,
        593,  598,  599,  604,  605,  606,  607,  608,  610,  611,  614,
        617,  621,  623,  624,  626,  628,  630,  632,  633,  635,  639]
# Out:
# [455,
#  460,
#  471,
#  473,
#  486,
#  487,
#  490,
#  494,
#  496,
#  499,
#  504,
#  511,
#  523,
#  528,
#  529,
#  535,
#  537,
#  538,
#  543,
#  558,
#  559,
#  560,
#  564,
#  566,
#  567,
#  571,
#  573,
#  575,
#  580,
#  581,
#  582,
#  583,
#  592,
#  593,
#  598,
#  599,
#  604,
#  605,
#  606,
#  607,
#  608,
#  610,
#  611,
#  614,
#  617,
#  621,
#  623,
#  624,
#  626,
#  628,
#  630,
#  632,
#  633,
#  635,
#  639]

# %%
[ 455,  460,  471,  473,  486,]
# Out:
# [455, 460, 471, 473, 486]

# %%
sample(new, [455, 460, 471, 473, 486])
# Out:
# {'data': [{'id': 455,
#    'area': 79397.5738357,
#    'length': 2247.47869093,
#    'map_fields': {'type': 'FeatureCollection',
#     'features': [{'id': '0',
#       'type': 'Feature',
#       'properties': {},
#       'geometry': {'type': 'Polygon',
#        'coordinates': [[[55.38278499974944, 56.752561000791644, 0.0],
#          [55.38365200116417, 56.752393000506856, 0.0],
#          [55.3835883080386, 56.75251897129307, 0.0],
#          [55.38501163777706, 56.75218020196677, 0.0],
#          [55.38469000007574, 56.75222100013454, 0.0],
#          [55.3843399999595, 56.75214100034861, 0.0],
#          [55.38447900107155, 56.75202400015357, 0.0],
#          [55.38449800084058, 56.75190900037285, 0.0],
#          [55.38428999988759, 56.75187600032193, 0.0],
#          [55.38423699996817, 56.75179800058721, 0.0],
#          [55.384373000942524, 56.751569000657284, 0.0],
#          [55.383970001293015, 56.75150200020887, 0.0],
# ...

# %%
new['intersected'] = new.intersecte.apply(lambda x: eval(x) if x.endswith(']') else [])

# %%
new['inter_all'] = new.ORIG_FID.apply(lambda x: set.union(*list(new[new.ORIG_FID == x].intersected.apply(lambda x: set(x)))))

# %%
new.inter_all = new.inter_all.apply(lambda x: str(x))

# %%
new = new.drop(columns=['intersecte', 'intersected'])

# %%
new
# Out:
#      level_0  index  Id  ORIG_FID    Shape_Leng    Shape_Area  \
# 0         40   1153   0       455  2.247479e+03  7.939757e+04
# 1         49   1165   0       460  2.759744e+04  2.245003e+06
# 2         57   1205   0       471  2.996381e+04  3.881749e+06
# 3         61   1210   0       473  3.054573e+03  9.642434e+04
# 4         67   1231   0       486  1.870872e+03  4.011511e+04
# ..       ...    ...  ..       ...           ...           ...
# 601     3651   8716   0      1414  5.465831e+06  9.115757e+08
# 602     3654   8719   0      1414  5.465831e+06  9.115757e+08
# 603     3674   8739   0      1414  5.465831e+06  9.115757e+08
# 604     3678   8743   0      1414  5.465831e+06  9.115757e+08
# 605     3680   8745   0      1414  5.465831e+06  9.115757e+08
#
#                                               geometry  \
# 0    POLYGON Z ((55.38278 56.75256 0.00000, 55.3836...
# 1    POLYGON Z ((55.47779 56.75493 0.00000, 55.4780...
# ...

# %%
new.to_file('XY4326/tmp2')

# %%
sample(new, [455,460, 471])
# Out:
# {'data': [{'id': 455,
#    'area': 79397.5738357,
#    'length': 2247.47869093,
#    'map_fields': {'type': 'FeatureCollection',
#     'features': [{'id': '0',
#       'type': 'Feature',
#       'properties': {},
#       'geometry': {'type': 'Polygon',
#        'coordinates': [[[55.38278499974944, 56.752561000791644, 0.0],
#          [55.38365200116417, 56.752393000506856, 0.0],
#          [55.3835883080386, 56.75251897129307, 0.0],
#          [55.38501163777706, 56.75218020196677, 0.0],
#          [55.38469000007574, 56.75222100013454, 0.0],
#          [55.3843399999595, 56.75214100034861, 0.0],
#          [55.38447900107155, 56.75202400015357, 0.0],
#          [55.38449800084058, 56.75190900037285, 0.0],
#          [55.38428999988759, 56.75187600032193, 0.0],
#          [55.38423699996817, 56.75179800058721, 0.0],
#          [55.384373000942524, 56.751569000657284, 0.0],
#          [55.383970001293015, 56.75150200020887, 0.0],
# ...

# %%
new.ORIG_FID.unique()
# Out:
# array([ 455,  460,  471,  473,  486,  487,  490,  494,  496,  499,  504,
#         511,  523,  528,  529,  535,  537,  538,  543,  558,  559,  560,
#         564,  566,  567,  571,  573,  575,  580,  581,  582,  583,  592,
#         593,  598,  599,  604,  605,  606,  607,  608,  610,  611,  614,
#         617,  621,  623,  624,  626,  628,  630,  632,  633,  635,  639,
#         641,  643,  644,  645,  646,  648,  649,  650,  651,  658,  660,
#         662,  668,  670,  671,  673,  685,  687,  688,  692,  694,  697,
#         698,  702,  710,  717,  719,  720,  721,  722,  729,  731,  733,
#         734,  736,  739,  740,  749,  751,  755,  762,  769,  774,  784,
#         794,  799,  805,  807,  812,  842,  858,  859,  862,  871,  896,
#         897,  898,  903,  904,  908,  909,  910,  911,  913,  916,  919,
#         922,  926,  927,  929,  940,  947,  954,  955,  958, 1005, 1010,
#        1011, 1018, 1021, 1027, 1030, 1032, 1033, 1041, 1045, 1046, 1048,
# ...

# %%
# %%time
# poly = df_all.loc[0].geometry
for j, rowj in df_all.iterrows():
    print(j)
    poly = rowj.geometry
    for i, row in df_target.iterrows():
        if poly.intersects(row.geometry):
            df_all.loc[j].intersected.append(i)
    print(df_all.loc[j].intersected)
#     if j == 50: break
    # until 123 clear

# %%
def find_intersected(df, df_target, idx):
    geoms = df[df.ORIG_FID == idx].geometry
    df['id_intersect'] = geoms.apply(
       lambda x: [i for i in range(len(geoms))
                     if x != geoms[i] and x.intersects(geoms[i])])

# %%
sample(df_all, [1,2,3])
# Out:
# {'data': [{'id': 1,
#    'area': 41.1405976866,
#    'length': 415.369280927,
#    'map_fields': {'type': 'FeatureCollection',
#     'features': [{'id': '0',
#       'type': 'Feature',
#       'properties': {},
#       'geometry': {'type': 'Polygon',
#        'coordinates': [[[57.006923041786855, 56.134307607677954, 0.0],
#          [57.006918009940485, 56.13430437704444, 0.0],
#          [57.0069165755412, 56.13430887129559, 0.0],
#          [57.009096685559335, 56.13571813851363, 0.0],
#          [57.006923041786855, 56.134307607677954, 0.0]]]},
#       'bbox': [57.0069165755412,
#        56.13430437704444,
#        57.009096685559335,
#        56.13571813851363]}],
#     'bbox': [57.0069165755412,
#      56.13430437704444,
#      57.009096685559335,
#      56.13571813851363]},
#    'map_ground_truth': {'type': 'FeatureCollection',
#     'features': [{'id': '0',
#       'type': 'Feature',
#       'properties': {},
#       'geometry': {'type': 'Polygon',
# ...

# %%
def plot_many(l, **kwargs):
    for p in l:
        x,y = p.exterior.xy
        plt.fill(x,y, **kwargs)

# %%
plot_many(df_all.geometry, color='red')
plot_many(df_target.geometry, color='blue')

# %%
idx = 2966
fields = df_all[df_all.ORIG_FID == idx].geometry
targets = df_target[df_target.ORIG_FID == idx].geometry
plot_many(fields, color='blue')
plot_many(targets, color='red')

# %%
df_all.ORIG_FID.value_counts()
pfx
# Out:
# 1141    1629
# 2901    1424
# 1642    1037
# 1414     626
# 1106     536
#         ...
# 1465       1
# 1449       1
# 3480       1
# 1417       1
# 2049       1
# Name: ORIG_FID, Length: 4863, dtype: int64

# %%
path = 'data/fields/fields.shp'
df = gpd.read_file(path)
df
# Out:
# Empty GeoDataFrame
# Columns: [ID, GRIDCODE, area, Shape_Leng, Shape_Area, geometry]
# Index: []

# %%
path = 'data/changes/changes.shp'
df = gpd.read_file(path)
df
# Out:
#       Id  ORIG_FID    Shape_Leng    Shape_Area          area2  \
# 0      0       604  2.247479e+03  7.939757e+04   21579.822452
# 1      0       604  2.247479e+03  7.939757e+04   45818.976439
# 2      0       613  2.759744e+04  2.245003e+06  397898.520648
# 3      0       613  2.759744e+04  2.245003e+06   10337.119067
# 4      0       650  2.996381e+04  3.881749e+06   60049.952412
# ...   ..       ...           ...           ...            ...
# 8256   0     18543  3.943298e+06  7.506543e+08   14121.788463
# 8257   0     18543  3.943298e+06  7.506543e+08   28136.044511
# 8258   0     18543  3.943298e+06  7.506543e+08  259081.164609
# 8259   0     18543  3.943298e+06  7.506543e+08  389309.389397
# 8260   0     18543  3.943298e+06  7.506543e+08   67562.123613
#
#                                                geometry
# 0     POLYGON Z ((55.38166 56.74943 0.00000, 55.3813...
# 1     POLYGON Z ((55.38327 56.75212 0.00000, 55.3833...
# ...

# %%
geoms = df.geometry.copy()

# %%
df['id_intersect'] = geoms.apply(
       lambda x: [i for i in range(len(geoms))
                     if x != geoms[i] and x.intersects(geoms[i])])

# %%
row = df[df.ORIG_FID == 2049].copy()

# %%
poly = row.geometry

# %%
poly.to_json()
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "11459", "type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[368738.01159999985, 6453331.687899999, 0.0], [368891.1085000001, 6453276.573000001, 0.0], [368891.0641000001, 6453276.574200001, 0.0], [368735.94209999964, 6453331.687899999, 0.0], [368738.01159999985, 6453331.687899999, 0.0]]]}, "bbox": [368735.94209999964, 6453276.573000001, 368891.1085000001, 6453331.687899999]}], "bbox": [368735.94209999964, 6453276.573000001, 368891.1085000001, 6453331.687899999]}'

# %%
[poly.to_json()]
# Out:
# ['{"type": "FeatureCollection", "features": [{"id": "11459", "type": "Feature", "properties": {}, "geometry": {"type": "Polygon", "coordinates": [[[368738.01159999985, 6453331.687899999, 0.0], [368891.1085000001, 6453276.573000001, 0.0], [368891.0641000001, 6453276.574200001, 0.0], [368735.94209999964, 6453331.687899999, 0.0], [368738.01159999985, 6453331.687899999, 0.0]]]}, "bbox": [368735.94209999964, 6453276.573000001, 368891.1085000001, 6453331.687899999]}], "bbox": [368735.94209999964, 6453276.573000001, 368891.1085000001, 6453331.687899999]}']

# %%
df.ORIG_FID.value_counts()
# Out:
# 1141    1629
# 2901    1424
# 1642    1037
# 1414     626
# 1106     536
#         ...
# 1465       1
# 1449       1
# 3480       1
# 1417       1
# 2049       1
# Name: ORIG_FID, Length: 4863, dtype: int64

# %%
geojsonio.display(states)
# Out:
# 'http://geojson.io/#data=data:application/json,%7B%22type%22%3A%20%22FeatureCollection%22%2C%20%22features%22%3A%20%5B%7B%22type%22%3A%20%22Feature%22%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22FeatureCollection%22%2C%20%22features%22%3A%20%5B%7B%22id%22%3A%20%220%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%22ObjectCode%22%3A%20%22738%22%2C%20%22ObjectID%22%3A%20%221%22%2C%20%22ObjectKey%22%3A%20%22S0000000738%22%2C%20%22ObjectName%22%3A%20%22102-%5Cufffd%5Cufffd%5Cufffd%5Cufffd%5Cufffd%20%5Cufffd%5Cufffd%5Cufffd%5Cufffd%5Cufffd%5Cufffd%5Cufffd%20%5Cufffd%5Cufffd%5Cufffd%22%2C%20%22SEM_1%22%3A%20%22%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Polygon%22%2C%20%22coordinates%22%3A%20%5B%5B%5B1314095.597953%2C%20479249.9877%5D%2C%20%5B1314093.127372%2C%20479246.572852%5D%2C%20%5B1314092.924004%2C%20479246.710366%5D%2C%20%5B1314091.519804%2C%20479244.897484%5D%2C%20%5B1314091.645699%2C%20479244.815169%5D%2C%20%5B1314089.263402%2C%20479241.721066%5D%2
# ...
